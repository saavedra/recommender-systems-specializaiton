# %% [markdown]
# ## Spreadsheet Layout
#
# This spreadsheet has 2 sheets: an Items sheet and Users sheet.
#
# The Items sheet contains the feature values for 100 items and 15 features, along with the weight (singular value) for each feature.
#
# The Users sheet contains the feature values for 20 users and those 15 features.
#
# ### Deliverables
#
# The output you are supposed to turn in consists of 3 parts: top movies for 2 features, and recommendations for a user.
#
# #### Top Movies
#
# For the first 2 features, provide the top 5 movies for that feature. Only provide the movie IDs.
#
# #### Recommendations
#
# Compute the top 5 movies for user 4469. Each movie should be scored with the function
#
# $$s_{ui} \sum_{f} a_{uf} \sigma_f b_{if}$$
#
# where $a_{uf}$ is the user weight for feature $f$, and $b_{if}$ is the item weight for feature $f$.
#
# Only provide the movie IDs of the 5 recommendations.

# %%
import pandas as pd
import numpy as np

# %%
df_items = pd.read_excel('assignment.xlsx', sheet_name='Items')

df_items.head()
# Out:
#   Unnamed: 0                                 Unnamed: 1           1  \
# 0        NaN                                     Weight  203.615022
# 1   Movie ID                                      Title         NaN
# 2         11  Star Wars: Episode IV - A New Hope (1977)   -0.106651
# 3         12                        Finding Nemo (2003)   -0.023980
# 4         13                        Forrest Gump (1994)   -0.157042
#
#             2           3          4          5          6          7  \
# 0  121.021257  102.797882  96.830823  85.133738  82.763808  79.835000
# 1         NaN         NaN        NaN        NaN        NaN        NaN
# 2   -0.094401    0.199949   0.025196  -0.064437   0.276259  -0.206928
# 3   -0.026960   -0.038067   0.248296  -0.118894  -0.068092   0.064117
# 4   -0.039889   -0.224400   0.062452   0.098026   0.078255  -0.047104
#
#            8          9         10         11         12         13  \
# 0  77.666420  74.607018  73.109410  69.096560  68.136588  66.480305
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2   0.054093  -0.025950  -0.088964  -0.117164   0.104474   0.049532
# 3   0.037390  -0.082457   0.037841  -0.067603  -0.017252  -0.069223
# 4   0.147743  -0.100540  -0.018727   0.076231   0.016129  -0.040507
#
#           14         15
# 0  64.513088  63.569436
# 1        NaN        NaN
# 2   0.140639  -0.031206
# 3   0.063107   0.159913
# 4  -0.275025  -0.052564

# %%
# format properly
item_weights = df_items.iloc[0, 2:].values

col_names = np.array(['movie_id', 'movie_name'] + [f'feat_{i}' for i in range(1, 16)])

df_items.columns = col_names

df_items = df_items.iloc[2:].set_index(['movie_id', 'movie_name'])

df_items.head()
# Out:
#                                                                feat_1  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -0.106651
# 12       Finding Nemo (2003)                                -0.023980
# 13       Forrest Gump (1994)                                -0.157042
# 14       American Beauty (1999)                             -0.044468
# 22       Pirates of the Caribbean: The Curse of the Blac...  0.036256
#
#                                                                feat_2  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -0.094401
# 12       Finding Nemo (2003)                                -0.026960
# 13       Forrest Gump (1994)                                -0.039889
# 14       American Beauty (1999)                              0.198715
# 22       Pirates of the Caribbean: The Curse of the Blac... -0.132421
#
#                                                                feat_3  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)           0.199949
# 12       Finding Nemo (2003)                                -0.038067
# 13       Forrest Gump (1994)                                -0.224400
# 14       American Beauty (1999)                             -0.006577
# 22       Pirates of the Caribbean: The Curse of the Blac...  0.036410
#
#                                                                feat_4  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)           0.025196
# 12       Finding Nemo (2003)                                 0.248296
# 13       Forrest Gump (1994)                                 0.062452
# 14       American Beauty (1999)                              0.008760
# 22       Pirates of the Caribbean: The Curse of the Blac...  0.007510
#
#                                                                feat_5  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -0.064437
# 12       Finding Nemo (2003)                                -0.118894
# 13       Forrest Gump (1994)                                 0.098026
# 14       American Beauty (1999)                              0.056093
# 22       Pirates of the Caribbean: The Curse of the Blac... -0.010657
#
#                                                                feat_6  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)           0.276259
# 12       Finding Nemo (2003)                                -0.068092
# 13       Forrest Gump (1994)                                 0.078255
# 14       American Beauty (1999)                             -0.020370
# 22       Pirates of the Caribbean: The Curse of the Blac... -0.065372
#
#                                                                feat_7  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -0.206928
# 12       Finding Nemo (2003)                                 0.064117
# 13       Forrest Gump (1994)                                -0.047104
# 14       American Beauty (1999)                             -0.046150
# 22       Pirates of the Caribbean: The Curse of the Blac...  0.092768
#
#                                                                feat_8  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)           0.054093
# 12       Finding Nemo (2003)                                 0.037390
# 13       Forrest Gump (1994)                                 0.147743
# 14       American Beauty (1999)                              0.007244
# 22       Pirates of the Caribbean: The Curse of the Blac...  0.003816
#
#                                                                feat_9  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -0.025950
# 12       Finding Nemo (2003)                                -0.082457
# 13       Forrest Gump (1994)                                -0.100540
# 14       American Beauty (1999)                              0.008791
# 22       Pirates of the Caribbean: The Curse of the Blac... -0.081900
#
#                                                               feat_10  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -0.088964
# 12       Finding Nemo (2003)                                 0.037841
# 13       Forrest Gump (1994)                                -0.018727
# 14       American Beauty (1999)                             -0.067562
# 22       Pirates of the Caribbean: The Curse of the Blac...  0.083958
#
#                                                               feat_11  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -0.117164
# 12       Finding Nemo (2003)                                -0.067603
# 13       Forrest Gump (1994)                                 0.076231
# 14       American Beauty (1999)                              0.063375
# 22       Pirates of the Caribbean: The Curse of the Blac...  0.167740
#
#                                                               feat_12  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)           0.104474
# 12       Finding Nemo (2003)                                -0.017252
# 13       Forrest Gump (1994)                                 0.016129
# 14       American Beauty (1999)                             -0.177547
# 22       Pirates of the Caribbean: The Curse of the Blac... -0.095340
#
#                                                               feat_13  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)           0.049532
# 12       Finding Nemo (2003)                                -0.069223
# 13       Forrest Gump (1994)                                -0.040507
# 14       American Beauty (1999)                             -0.100531
# 22       Pirates of the Caribbean: The Curse of the Blac...  0.175285
#
#                                                               feat_14  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)           0.140639
# 12       Finding Nemo (2003)                                 0.063107
# 13       Forrest Gump (1994)                                -0.275025
# 14       American Beauty (1999)                              0.068353
# 22       Pirates of the Caribbean: The Curse of the Blac...  0.106542
#
#                                                               feat_15
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -0.031206
# 12       Finding Nemo (2003)                                 0.159913
# 13       Forrest Gump (1994)                                -0.052564
# 14       American Beauty (1999)                             -0.085437
# 22       Pirates of the Caribbean: The Curse of the Blac... -0.287540

# %% [markdown]
# #### Ex. 1) Top Movies
#
# For the first 2 features, provide the top 5 movies for that feature. Only provide the movie IDs.

# %%
df_items.feat_1.sort_values(ascending=False).head()
# Out:
# movie_id  movie_name
# 4327      Charlie's Angels (2000)              0.281990
# 414       Batman Forever (1995)                0.218089
# 3049      Ace Ventura: Pet Detective (1994)    0.190879
# 8467      Dumb & Dumber (1994)                 0.190638
# 854       The Mask (1994)                      0.158601
# Name: feat_1, dtype: float64

# %%
df_items.feat_2.sort_values(ascending=False).head()
# Out:
# movie_id  movie_name
# 14        American Beauty (1999)                          0.198715
# 680       Pulp Fiction (1994)                             0.189565
# 24        Kill Bill: Vol. 1 (2003)                        0.181570
# 275       Fargo (1996)                                    0.161559
# 38        Eternal Sunshine of the Spotless Mind (2004)    0.161058
# Name: feat_2, dtype: float64

# %% [markdown]
# #### Ex. 2) Recommendations
#
# Compute the top 5 movies for user 4469. Each movie should be scored with the function
#
# $$s_{ui} \sum_{f} a_{uf} \sigma_f b_{if}$$
#
# where $a_{uf}$ is the user weight for feature $f$, and $b_{if}$ is the item weight for feature $f$.
#
# Only provide the movie IDs of the 5 recommendations.

# %%
# weights the movie factors by the factors weight
df_items_weighted = pd.DataFrame(df_items.values * np.array(item_weights))
df_items_weighted.columns = df_items.columns 
df_items_weighted.index = df_items.index

# %%
print(df_items_weighted.shape)
df_items_weighted.head()
# Out:
# (100, 15)
#                                                                 feat_1  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -21.715813
# 12       Finding Nemo (2003)                                 -4.882766
# 13       Forrest Gump (1994)                                -31.976067
# 14       American Beauty (1999)                              -9.054366
# 22       Pirates of the Caribbean: The Curse of the Blac...   7.382226
#
#                                                                 feat_2  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -11.424585
# 12       Finding Nemo (2003)                                 -3.262738
# 13       Forrest Gump (1994)                                 -4.827393
# 14       American Beauty (1999)                              24.048763
# 22       Pirates of the Caribbean: The Curse of the Blac... -16.025797
#
#                                                                 feat_3  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)           20.554339
# 12       Finding Nemo (2003)                                 -3.913246
# 13       Forrest Gump (1994)                                -23.067861
# 14       American Beauty (1999)                              -0.676076
# 22       Pirates of the Caribbean: The Curse of the Blac...   3.742896
#
#                                                                 feat_4  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)            2.439722
# 12       Finding Nemo (2003)                                 24.042696
# 13       Forrest Gump (1994)                                  6.047319
# 14       American Beauty (1999)                                 0.8482
# 22       Pirates of the Caribbean: The Curse of the Blac...   0.727223
#
#                                                                 feat_5  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)           -5.485769
# 12       Finding Nemo (2003)                                -10.121929
# 13       Forrest Gump (1994)                                  8.345353
# 14       American Beauty (1999)                                 4.7754
# 22       Pirates of the Caribbean: The Curse of the Blac...  -0.907291
#
#                                                                 feat_6  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)           22.864286
# 12       Finding Nemo (2003)                                 -5.635559
# 13       Forrest Gump (1994)                                  6.476658
# 14       American Beauty (1999)                              -1.685928
# 22       Pirates of the Caribbean: The Curse of the Blac...  -5.410461
#
#                                                                 feat_7  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -16.520092
# 12       Finding Nemo (2003)                                  5.118772
# 13       Forrest Gump (1994)                                 -3.760545
# 14       American Beauty (1999)                              -3.684385
# 22       Pirates of the Caribbean: The Curse of the Blac...   7.406146
#
#                                                                 feat_8  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)            4.201176
# 12       Finding Nemo (2003)                                   2.90398
# 13       Forrest Gump (1994)                                 11.474657
# 14       American Beauty (1999)                               0.562623
# 22       Pirates of the Caribbean: The Curse of the Blac...   0.296338
#
#                                                                feat_9  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -1.936072
# 12       Finding Nemo (2003)                                -6.151891
# 13       Forrest Gump (1994)                                -7.500995
# 14       American Beauty (1999)                              0.655904
# 22       Pirates of the Caribbean: The Curse of the Blac... -6.110314
#
#                                                               feat_10  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)          -6.504127
# 12       Finding Nemo (2003)                                 2.766519
# 13       Forrest Gump (1994)                                -1.369106
# 14       American Beauty (1999)                             -4.939413
# 22       Pirates of the Caribbean: The Curse of the Blac...  6.138135
#
#                                                                feat_11  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)           -8.095605
# 12       Finding Nemo (2003)                                 -4.671159
# 13       Forrest Gump (1994)                                  5.267317
# 14       American Beauty (1999)                               4.379018
# 22       Pirates of the Caribbean: The Curse of the Blac...  11.590246
#
#                                                                feat_12  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)            7.118496
# 12       Finding Nemo (2003)                                 -1.175484
# 13       Forrest Gump (1994)                                  1.098988
# 14       American Beauty (1999)                             -12.097423
# 22       Pirates of the Caribbean: The Curse of the Blac...  -6.496168
#
#                                                                feat_13  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)              3.2929
# 12       Finding Nemo (2003)                                 -4.601981
# 13       Forrest Gump (1994)                                 -2.692918
# 14       American Beauty (1999)                              -6.683317
# 22       Pirates of the Caribbean: The Curse of the Blac...  11.652975
#
#                                                                feat_14  \
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)             9.07308
# 12       Finding Nemo (2003)                                   4.07123
# 13       Forrest Gump (1994)                                -17.742731
# 14       American Beauty (1999)                               4.409654
# 22       Pirates of the Caribbean: The Curse of the Blac...   6.873359
#
#                                                                feat_15
# movie_id movie_name
# 11       Star Wars: Episode IV - A New Hope (1977)            -1.98374
# 12       Finding Nemo (2003)                                 10.165575
# 13       Forrest Gump (1994)                                 -3.341438
# 14       American Beauty (1999)                              -5.431168
# 22       Pirates of the Caribbean: The Curse of the Blac...  -18.27873

# %%
df_users = pd.read_excel('assignment.xlsx', sheet_name='Users', index_col=0)

df_users.columns = [f'feat_{c}' for c in df_users.columns]
df_users.index.name = 'user_id'

df_users.head()
# Out:
#            feat_1    feat_2    feat_3    feat_4    feat_5    feat_6    feat_7  \
# user_id
# 4768    -0.014298  0.014642 -0.008921  0.014074 -0.017659  0.018015  0.005764
# 156     -0.013291 -0.016269 -0.009024 -0.000084 -0.003538  0.019479 -0.010982
# 5323    -0.008081 -0.008262 -0.005240  0.001877 -0.007379 -0.000531  0.012647
# 174     -0.015941 -0.024773 -0.001699  0.005521  0.023275 -0.007985 -0.003707
# 4529    -0.001024 -0.009292 -0.010646  0.015831 -0.013370 -0.012996 -0.001516
#
#            feat_8    feat_9   feat_10   feat_11   feat_12   feat_13   feat_14  \
# user_id
# 4768    -0.010051  0.014683  0.007715  0.010227  0.043056  0.000872 -0.014774
# 156     -0.007748 -0.001340  0.014136 -0.001195 -0.005888  0.005631  0.014152
# 5323     0.011586  0.004024  0.000081 -0.008868 -0.002357  0.013291  0.006782
# 174     -0.009816 -0.015222  0.021099  0.011536 -0.009982  0.004509 -0.020597
# 4529    -0.005744  0.006796 -0.018666 -0.017129 -0.016093 -0.004893  0.016069
#
#           feat_15
# user_id
# 4768    -0.004907
# 156      0.022560
# 5323    -0.013740
# 174      0.006358
# 4529     0.012877

# %%
# performs a cross join to gather all permutations of user and movie
df_cross_joined = pd.merge(
    df_items_weighted.reset_index().assign(key=1),
    df_users.reset_index().assign(key=1)
, on='key')

print(df_cross_joined.shape)
df_cross_joined.head()
# Out:
# (2500, 34)
#    movie_id                                 movie_name   feat_1_x   feat_2_x  \
# 0        11  Star Wars: Episode IV - A New Hope (1977) -21.715813 -11.424585
# 1        11  Star Wars: Episode IV - A New Hope (1977) -21.715813 -11.424585
# 2        11  Star Wars: Episode IV - A New Hope (1977) -21.715813 -11.424585
# 3        11  Star Wars: Episode IV - A New Hope (1977) -21.715813 -11.424585
# 4        11  Star Wars: Episode IV - A New Hope (1977) -21.715813 -11.424585
#
#     feat_3_x  feat_4_x  feat_5_x   feat_6_x   feat_7_x  feat_8_x  ...  \
# 0  20.554339  2.439722 -5.485769  22.864286 -16.520092  4.201176  ...
# 1  20.554339  2.439722 -5.485769  22.864286 -16.520092  4.201176  ...
# 2  20.554339  2.439722 -5.485769  22.864286 -16.520092  4.201176  ...
# 3  20.554339  2.439722 -5.485769  22.864286 -16.520092  4.201176  ...
# 4  20.554339  2.439722 -5.485769  22.864286 -16.520092  4.201176  ...
#
#    feat_6_y  feat_7_y  feat_8_y  feat_9_y feat_10_y feat_11_y feat_12_y  \
# 0  0.018015  0.005764 -0.010051  0.014683  0.007715  0.010227  0.043056
# 1  0.019479 -0.010982 -0.007748 -0.001340  0.014136 -0.001195 -0.005888
# 2 -0.000531  0.012647  0.011586  0.004024  0.000081 -0.008868 -0.002357
# 3 -0.007985 -0.003707 -0.009816 -0.015222  0.021099  0.011536 -0.009982
# 4 -0.012996 -0.001516 -0.005744  0.006796 -0.018666 -0.017129 -0.016093
#
#    feat_13_y  feat_14_y  feat_15_y
# 0   0.000872  -0.014774  -0.004907
# 1   0.005631   0.014152   0.022560
# 2   0.013291   0.006782  -0.013740
# 3   0.004509  -0.020597   0.006358
# 4  -0.004893   0.016069   0.012877
#
# [5 rows x 34 columns]

# %%
df_user_movie_factors = pd.DataFrame({f'feat_{i}': df_cross_joined[f'feat_{i}_x'] * df_cross_joined[f'feat_{i}_y'] for i in range(1, 16)})

df_user_movie_factors.head()
# Out:
#      feat_1    feat_2    feat_3    feat_4    feat_5    feat_6    feat_7  \
# 0  0.310494 -0.167281 -0.183361  0.034337  0.096872  0.411909 -0.095222
# 1  0.288621  0.185871 -0.185474 -0.000204   0.01941  0.445373   0.18142
# 2  0.175481  0.094386 -0.107706   0.00458  0.040477 -0.012135 -0.208935
# 3  0.346162  0.283026 -0.034932  0.013469 -0.127682  -0.18256  0.061239
# 4  0.022244  0.106154 -0.218814  0.038624  0.073344 -0.297138   0.02505
#
#      feat_8    feat_9   feat_10   feat_11   feat_12   feat_13   feat_14  \
# 0 -0.042228 -0.028428  -0.05018 -0.082791  0.306493  0.002871 -0.134044
# 1 -0.032551  0.002594 -0.091941  0.009672 -0.041917  0.018544  0.128404
# 2  0.048675 -0.007791 -0.000527  0.071789 -0.016782  0.043767  0.061531
# 3 -0.041239  0.029471 -0.137229 -0.093388 -0.071057  0.014849 -0.186882
# 4 -0.024132 -0.013157  0.121405  0.138668 -0.114555 -0.016113  0.145792
#
#     feat_15
# 0  0.009735
# 1 -0.044754
# 2  0.027257
# 3 -0.012612
# 4 -0.025545

# %%
user_movie_preference = pd.concat([
    df_cross_joined[['user_id', 'movie_id', 'movie_name']],
    df_user_movie_factors.sum(axis=1).rename('preference')
], axis=1).set_index(['user_id', 'movie_id', 'movie_name'])['preference']

user_movie_preference.head()
# Out:
# user_id  movie_id  movie_name
# 4768     11        Star Wars: Episode IV - A New Hope (1977)    0.389174
# 156      11        Star Wars: Episode IV - A New Hope (1977)    0.883069
# 5323     11        Star Wars: Episode IV - A New Hope (1977)    0.214068
# 174      11        Star Wars: Episode IV - A New Hope (1977)   -0.139366
# 4529     11        Star Wars: Episode IV - A New Hope (1977)   -0.038172
# Name: preference, dtype: object

# %%
# top recommendations for user 4469
user_movie_preference.loc[4469].sort_values(ascending=False).head()
# Out:
# movie_id  movie_name
# 278       The Shawshank Redemption (1994)     0.20768
# 453       A Beautiful Mind (2001)            0.183286
# 98        Gladiator (2000)                   0.173611
# 238       The Godfather (1972)                0.17218
# 13        Forrest Gump (1994)                0.170744
# Name: preference, dtype: object
